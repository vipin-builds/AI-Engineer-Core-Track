# %% [markdown]
# <a href="https://colab.research.google.com/github/vipin-builds/AI-Engineer-Core-Track/blob/main/notes/llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #There are the basic things to look for when one chooses a LLM. First and foremost there is no 1 size fits all.
#
# ### Open-source or closed
# ### Chat/Reasoning/Hybrid
# ### Release date and knowledge cut-off
# ### Parameters
# ### Training tokens
# ### Context window
#
# # More than basics
#
# ### Inference cost
#   ##### API charge or Runtime compute
# ### Training cost (If any training is required)
# ### Build cost (cost to build it)
# ### Time to market (development time)
# ### Rate limits (how often can we call them)
# ### Speed
#   ##### Gemini Flash Lite blazingly fast
#   ##### GPT 5 Nano is quite fast
#   ##### GPT 4.1 Nano is really fast
# ### Latency
#   ##### Time until it starts respoding
# ### License
